# %%
# ================= IMPORTS ================= #
import matplotlib.pyplot as plt
import numpy as nps
import qutip as qt

# ================= CONFIG ================= #
b = qt.Bloch(figsize=[2,2])
b.render()
b.show()
