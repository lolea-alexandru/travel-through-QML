# %%
# ================= IMPORTS ================= #
from matplotlib import pyplot, animation
import numpy as np
import qutip as qt
from qutip_qip.operations import rx

# ================= CONFIG ================= #
b = qt.Bloch(figsize=[3,3])

# define starting state (|0>)
init_state = qt.basis(2, 0)
b.add_states(init_state)

# get rotated
#? Why does the manual R_x differ from the good R_x? To figure out later
theta = np.pi / 4
# manual_R_x = (-1j * (theta / 2) * qt.sigmax()).expm()
# print(manual_R_x.full())
# b.add_states(manual_R_x * init_state)
xs

R_x = rx(theta)
rotated_init_state = R_x * init_state
b.add_states(rotated_init_state)

b.render()
b.show()
